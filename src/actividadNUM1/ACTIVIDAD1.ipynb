# %%
from src.funciones import simular_rondas

# ============================
# DATOS DE LAS RONDAS
# ============================
evaluaciones = [
    # Ronda 1
    {                                                                                             
        'EquipoA': {'innovacion': 2, 'presentacion': 1, 'errores': True},                
        'EquipoB': {'innovacion': 1, 'presentacion': 0, 'errores': False},              
        'EquipoC': {'innovacion': 1, 'presentacion': 2, 'errores': True},               
        'EquipoD': {'innovacion': 0, 'presentacion': 1, 'errores': False},              
        'EquipoE': {'innovacion': 1, 'presentacion': 1, 'errores': False}               
    },
    # Ronda 2
    {
        'EquipoA': {'innovacion': 0, 'presentacion': 2, 'errores': False},
        'EquipoB': {'innovacion': 2, 'presentacion': 0, 'errores': True},
        'EquipoC': {'innovacion': 1, 'presentacion': 1, 'errores': False},
        'EquipoD': {'innovacion': 2, 'presentacion': 1, 'errores': True},
        'EquipoE': {'innovacion': 0, 'presentacion': 1, 'errores': False}
    },
    # Ronda 3
    {
        'EquipoA': {'innovacion': 3, 'presentacion': 2, 'errores': False},
        'EquipoB': {'innovacion': 1, 'presentacion': 1, 'errores': True},
        'EquipoC': {'innovacion': 2, 'presentacion': 0, 'errores': False},
        'EquipoD': {'innovacion': 1, 'presentacion': 3, 'errores': True},
        'EquipoE': {'innovacion': 2, 'presentacion': 2, 'errores': False}
    },
    # Ronda 4
    {
        'EquipoA': {'innovacion': 1, 'presentacion': 3, 'errores': True},
        'EquipoB': {'innovacion': 2, 'presentacion': 2, 'errores': False},
        'EquipoC': {'innovacion': 3, 'presentacion': 1, 'errores': False},
        'EquipoD': {'innovacion': 0, 'presentacion': 2, 'errores': True},
        'EquipoE': {'innovacion': 2, 'presentacion': 0, 'errores': False}
    },
    # Ronda 5
    {
        'EquipoA': {'innovacion': 2, 'presentacion': 2, 'errores': False},
        'EquipoB': {'innovacion': 1, 'presentacion': 3, 'errores': True},
        'EquipoC': {'innovacion': 0, 'presentacion': 2, 'errores': False},
        'EquipoD': {'innovacion': 3, 'presentacion': 1, 'errores': False},
        'EquipoE': {'innovacion': 2, 'presentacion': 3, 'errores': True}
    }
]

# ============================
# PUNTOS ASIGNADOS A CADA CRITERIO
# ============================
diccionario_puntos = {
    'innovacion': 3,
    'presentacion': 1,
    'errores': -1 
}

# ============================
# EJECUCIÓN DE LA SIMULACIÓN
# ============================
simular_rondas(evaluaciones, diccionario_puntos)
# Out:
# Ronda 1:
#
# Estadísticas de la ronda (mer: EquipoA)
# Equipo     INNOVACION   PRESENTACION    ERRORES    Puntos   mer
# ----------------------------------------------------------------------
# EquipoA    2            1               1          6        1
# EquipoC    1            2               1          4        0
# EquipoE    1            1               0          4        0
# EquipoB    1            0               0          3        0
# EquipoD    0            1               0          1        0
# ------------------------------------------------------------
#
# Estadísticas actualizadas
# Equipo     INNOVACION   PRESENTACION    ERRORES    Puntos   mer
# ----------------------------------------------------------------------
# EquipoA    2            1               1          6        1
# EquipoC    1            2               1          4        0
# EquipoE    1            1               0          4        0
# EquipoB    1            0               0          3        0
# EquipoD    0            1               0          1        0
# ------------------------------------------------------------
# ____________________________________________________________________________________________________
#
# Ronda 2:
#
# Estadísticas de la ronda (mer: EquipoD)
# Equipo     INNOVACION   PRESENTACION    ERRORES    Puntos   mer
# ----------------------------------------------------------------------
# EquipoD    2            1               1          6        1
# EquipoB    2            0               1          5        0
# EquipoC    1            1               0          4        0
# EquipoA    0            2               0          2        0
# EquipoE    0            1               0          1        0
# ------------------------------------------------------------
#
# Estadísticas actualizadas
# Equipo     INNOVACION   PRESENTACION    ERRORES    Puntos   mer
# ----------------------------------------------------------------------
# EquipoA    2            3               1          8        1
# EquipoB    3            0               1          8        0
# EquipoC    2            3               1          8        0
# EquipoD    2            2               1          7        1
# EquipoE    1            2               0          5        0
# ------------------------------------------------------------
# ____________________________________________________________________________________________________
#
# Ronda 3:
#
# Estadísticas de la ronda (mer: EquipoA)
# Equipo     INNOVACION   PRESENTACION    ERRORES    Puntos   mer
# ----------------------------------------------------------------------
# EquipoA    3            2               0          11       1
# EquipoE    2            2               0          8        0
# EquipoC    2            0               0          6        0
# EquipoD    1            3               1          5        0
# EquipoB    1            1               1          3        0
# ------------------------------------------------------------
#
# Estadísticas actualizadas
# Equipo     INNOVACION   PRESENTACION    ERRORES    Puntos   mer
# ----------------------------------------------------------------------
# EquipoA    5            5               1          19       2
# EquipoC    4            3               1          14       0
# EquipoE    3            4               0          13       0
# EquipoD    3            5               2          12       1
# EquipoB    4            1               2          11       0
# ------------------------------------------------------------
# ____________________________________________________________________________________________________
#
# Ronda 4:
#
# Estadísticas de la ronda (mer: EquipoC)
# Equipo     INNOVACION   PRESENTACION    ERRORES    Puntos   mer
# ----------------------------------------------------------------------
# EquipoC    3            1               0          10       1
# EquipoB    2            2               0          8        0
# EquipoE    2            0               0          6        0
# EquipoA    1            3               1          5        0
# EquipoD    0            2               1          1        0
# ------------------------------------------------------------
#
# Estadísticas actualizadas
# Equipo     INNOVACION   PRESENTACION    ERRORES    Puntos   mer
# ----------------------------------------------------------------------
# EquipoA    6            8               2          24       2
# EquipoC    7            4               1          24       1
# EquipoB    6            3               2          19       0
# EquipoE    5            4               0          19       0
# EquipoD    3            7               3          13       1
# ------------------------------------------------------------
# ____________________________________________________________________________________________________
#
# Ronda 5:
#
# Estadísticas de la ronda (mer: EquipoD)
# Equipo     INNOVACION   PRESENTACION    ERRORES    Puntos   mer
# ----------------------------------------------------------------------
# EquipoD    3            1               0          10       1
# EquipoA    2            2               0          8        0
# EquipoE    2            3               1          8        0
# EquipoB    1            3               1          5        0
# EquipoC    0            2               0          2        0
# ------------------------------------------------------------
#
# Estadísticas actualizadas
# Equipo     INNOVACION   PRESENTACION    ERRORES    Puntos   mer
# ----------------------------------------------------------------------
# EquipoA    8            10              2          32       2
# EquipoE    7            7               1          27       0
# EquipoC    7            6               1          26       1
# EquipoB    7            6               3          24       0
# EquipoD    6            8               3          23       2
# ------------------------------------------------------------
# ____________________________________________________________________________________________________
